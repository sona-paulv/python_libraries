# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten,Dense

(xtrain,ytrain),(xtest,ytest)=tf.keras.datasets.mnist.load_data()

# %%
gray_scale=255 #255 is used to convert data into gray scale

xtrain=xtrain.astype('float32')/gray_scale
xtest=xtest.astype('float32')/gray_scale

print('feature matrix (xtrain):', xtrain.shape)
print('target matrix (ytrain):', ytrain.shape)
print('feature matrix (xtest):', xtest.shape)
print('target matrix (ytest):', ytest.shape)
# Out:
# feature matrix (xtrain): (60000, 28, 28)
# target matrix (ytrain): (60000,)
# feature matrix (xtest): (10000, 28, 28)
# target matrix (ytest): (10000,)

# %%
fig, ax=plt.subplots(10,10)
k=0
for i in range(10):
  for j in range(10):
    ax[i][j].imshow(xtrain[k].reshape(28,28),aspect='auto')
    k +=1
plt.show()

# %%
model=Sequential([
    Flatten(input_shape=(28,28)),
    Dense(256,activation='sigmoid'),
    Dense(128,activation='sigmoid'),
    Dense(10,activation='softmax'),
])

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
mod=model.fit(xtrain,ytrain,epochs=10,
              batch_size=2000,
              validation_split=0.2)
print(mod)
# Out:
# Epoch 1/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.3233 - loss: 2.1900 - val_accuracy: 0.7159 - val_loss: 1.6503
# Epoch 2/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.7185 - loss: 1.4696 - val_accuracy: 0.8138 - val_loss: 0.9618
# Epoch 3/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.8081 - loss: 0.8827 - val_accuracy: 0.8653 - val_loss: 0.6260
# Epoch 4/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.8583 - loss: 0.6112 - val_accuracy: 0.8889 - val_loss: 0.4690
# Epoch 5/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.8879 - loss: 0.4662 - val_accuracy: 0.9024 - val_loss: 0.3896
# Epoch 6/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - accuracy: 0.8977 - loss: 0.3972 - val_accuracy: 0.9101 - val_loss: 0.3432
# Epoch 7/10
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9044 - loss: 0.3553 - val_accuracy: 0.9160 - val_loss: 0.3122
# Epoch 8/10
# ...

# %%
results=model.evaluate(xtest,ytest,verbose=0)
print('test loss, test accuracy:',results)
# Out:
# test loss, test accuracy: [0.2742484509944916, 0.9243999719619751]
