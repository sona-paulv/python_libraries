# %%
import pandas as pd
data=pd.read_csv('/content/loan_sanction_train.csv')
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
data=data.drop(['Loan_ID'],axis=1)

# %%
mode = data['Gender'].mode()
mode
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
data['Gender'].fillna(mode,inplace=True)
data
# Out:
# <ipython-input-163-8112471271cf>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Gender'].fillna(mode,inplace=True)
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
labelencoder
# Out:
# LabelEncoder()

# %%
data['gend']=labelencoder.fit_transform(data['Gender'])
data
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
data=data.drop(['Gender'],axis=1)
data
# Out:
#     Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0        No          0      Graduate            No             5849
# 1       Yes          1      Graduate            No             4583
# 2       Yes          0      Graduate           Yes             3000
# 3       Yes          0  Not Graduate            No             2583
# 4        No          0      Graduate            No             6000
# ..      ...        ...           ...           ...              ...
# 609      No          0      Graduate            No             2900
# 610     Yes         3+      Graduate            No             4106
# 611     Yes          1      Graduate            No             8072
# 612     Yes          2      Graduate            No             7583
# 613      No          0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# ...

# %%
mod = data['Married'].mode()[0]
data['Married'].fillna(mod, inplace=True)
data.head()
# Out:
# <ipython-input-167-e19051caa74a>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Married'].fillna(mod, inplace=True)
#   Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      No          0      Graduate            No             5849
# 1     Yes          1      Graduate            No             4583
# 2     Yes          0      Graduate           Yes             3000
# 3     Yes          0  Not Graduate            No             2583
# ...

# %%
data['marry']=labelencoder.fit_transform(data['Married'])
data
# Out:
#     Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0        No          0      Graduate            No             5849
# 1       Yes          1      Graduate            No             4583
# 2       Yes          0      Graduate           Yes             3000
# 3       Yes          0  Not Graduate            No             2583
# 4        No          0      Graduate            No             6000
# ..      ...        ...           ...           ...              ...
# 609      No          0      Graduate            No             2900
# 610     Yes         3+      Graduate            No             4106
# 611     Yes          1      Graduate            No             8072
# 612     Yes          2      Graduate            No             7583
# 613      No          0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# ...

# %%
del data['Married']
data
# Out:
#     Dependents     Education Self_Employed  ApplicantIncome  \
# 0            0      Graduate            No             5849
# 1            1      Graduate            No             4583
# 2            0      Graduate           Yes             3000
# 3            0  Not Graduate            No             2583
# 4            0      Graduate            No             6000
# ..         ...           ...           ...              ...
# 609          0      Graduate            No             2900
# 610         3+      Graduate            No             4106
# 611          1      Graduate            No             8072
# 612          2      Graduate            No             7583
# 613          0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# 1               1508.0       128.0             360.0             1.0
# ...

# %%
data['Dependents'].fillna(data['Dependents'].mode()[0],inplace=True)
data
# Out:
# <ipython-input-170-ba4ad02d1e1d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Dependents'].fillna(data['Dependents'].mode()[0],inplace=True)
#     Dependents     Education Self_Employed  ApplicantIncome  \
# 0            0      Graduate            No             5849
# 1            1      Graduate            No             4583
# 2            0      Graduate           Yes             3000
# 3            0  Not Graduate            No             2583
# ...

# %%
data['dependent']=labelencoder.fit_transform(data['Dependents'])
data
# Out:
#     Dependents     Education Self_Employed  ApplicantIncome  \
# 0            0      Graduate            No             5849
# 1            1      Graduate            No             4583
# 2            0      Graduate           Yes             3000
# 3            0  Not Graduate            No             2583
# 4            0      Graduate            No             6000
# ..         ...           ...           ...              ...
# 609          0      Graduate            No             2900
# 610         3+      Graduate            No             4106
# 611          1      Graduate            No             8072
# 612          2      Graduate            No             7583
# 613          0      Graduate           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# 1               1508.0       128.0             360.0             1.0
# ...

# %%
del data['Dependents']

# %%
data['education']=labelencoder.fit_transform(data['Education'])
data
# Out:
#         Education Self_Employed  ApplicantIncome  CoapplicantIncome  \
# 0        Graduate            No             5849                0.0
# 1        Graduate            No             4583             1508.0
# 2        Graduate           Yes             3000                0.0
# 3    Not Graduate            No             2583             2358.0
# 4        Graduate            No             6000                0.0
# ..            ...           ...              ...                ...
# 609      Graduate            No             2900                0.0
# 610      Graduate            No             4106                0.0
# 611      Graduate            No             8072              240.0
# 612      Graduate            No             7583                0.0
# 613      Graduate           Yes             4583                0.0
#
#      LoanAmount  Loan_Amount_Term  Credit_History Property_Area Loan_Status  \
# ...

# %%
del data['Education']

# %%
data['Self_Employed'].fillna(data['Self_Employed'].mode()[0],inplace=True)
# Out:
# <ipython-input-175-1a4560ef90a4>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Self_Employed'].fillna(data['Self_Employed'].mode()[0],inplace=True)

# %%
data['self_employed']=labelencoder.fit_transform(data['Self_Employed'])
data
# Out:
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0              No             5849                0.0         NaN
# 1              No             4583             1508.0       128.0
# 2             Yes             3000                0.0        66.0
# 3              No             2583             2358.0       120.0
# 4              No             6000                0.0       141.0
# ..            ...              ...                ...         ...
# 609            No             2900                0.0        71.0
# 610            No             4106                0.0        40.0
# 611            No             8072              240.0       253.0
# 612            No             7583                0.0       187.0
# 613           Yes             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History Property_Area Loan_Status  gend  marry  \
# 0               360.0             1.0         Urban           Y     1      0
# ...

# %%
del  data['Self_Employed']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ApplicantIncome    614 non-null    int64
#  1   CoapplicantIncome  614 non-null    float64
#  2   LoanAmount         592 non-null    float64
#  3   Loan_Amount_Term   600 non-null    float64
#  4   Credit_History     564 non-null    float64
#  5   Property_Area      614 non-null    object
#  6   Loan_Status        614 non-null    object
#  7   gend               614 non-null    int64
#  8   marry              614 non-null    int64
#  9   dependent          614 non-null    int64
#  10  education          614 non-null    int64
#  11  self_employed      614 non-null    int64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 57.7+ KB

# %%
#hist plot is do for in this case
# find out loan amount mean,median or mode and loan amt has skweness so it is median
#if it is bell curved it is mean
# if it is categorical data take mode
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(data['LoanAmount'],hist=False)
plt.show()
# Out:
# <ipython-input-179-7addf8ea92fd>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['LoanAmount'],hist=False)

# %%
median=data['LoanAmount'].median()
median
# Out:
# 128.0

# %%
data['LoanAmount'].fillna(median,inplace=True)
data
# Out:
# <ipython-input-187-cc979e577c49>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['LoanAmount'].fillna(median,inplace=True)
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0       128.0             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(data['Loan_Amount_Term'],hist=False)
plt.show()
# Out:
# <ipython-input-185-8df158d695ce>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Loan_Amount_Term'],hist=False)

# %%
median=data['Loan_Amount_Term'].median()
median
# Out:
# 360.0

# %%
data['Loan_Amount_Term'].fillna(median,inplace=True)
data
# Out:
# <ipython-input-189-2461ae80174a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Loan_Amount_Term'].fillna(median,inplace=True)
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0       128.0             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(data['Credit_History'],hist=False)
plt.show()
# Out:
# <ipython-input-191-d9f8478f8c03>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Credit_History'],hist=False)

# %%
median=data['Credit_History'].median()
median
# Out:
# 1.0

# %%
data['Credit_History'].fillna(median,inplace=True)
data
# Out:
# <ipython-input-193-92a064e76e11>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Credit_History'].fillna(median,inplace=True)
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0       128.0             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# ...

# %%
data['property_area']=labelencoder.fit_transform(data['Property_Area'])
data
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0       128.0             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status  gend  marry  dependent  \
# ...

# %%
del data['Property_Area']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ApplicantIncome    614 non-null    int64
#  1   CoapplicantIncome  614 non-null    float64
#  2   LoanAmount         614 non-null    float64
#  3   Loan_Amount_Term   614 non-null    float64
#  4   Credit_History     614 non-null    float64
#  5   Loan_Status        614 non-null    object
#  6   gend               614 non-null    int64
#  7   marry              614 non-null    int64
#  8   dependent          614 non-null    int64
#  9   education          614 non-null    int64
#  10  self_employed      614 non-null    int64
#  11  property_area      614 non-null    int64
# dtypes: float64(4), int64(7), object(1)
# memory usage: 57.7+ KB

# %%
data['loan_status']=labelencoder.fit_transform(data['Loan_Status'])
data
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0       128.0             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Loan_Status  gend  marry  dependent  education  \
# ...

# %%
del data['Loan_Status']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ApplicantIncome    614 non-null    int64
#  1   CoapplicantIncome  614 non-null    float64
#  2   LoanAmount         614 non-null    float64
#  3   Loan_Amount_Term   614 non-null    float64
#  4   Credit_History     614 non-null    float64
#  5   gend               614 non-null    int64
#  6   marry              614 non-null    int64
#  7   dependent          614 non-null    int64
#  8   education          614 non-null    int64
#  9   self_employed      614 non-null    int64
#  10  property_area      614 non-null    int64
#  11  loan_status        614 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 57.7 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
corr_data = data.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_data, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
y=data[['LoanAmount']]
x=data[['ApplicantIncome','Loan_Amount_Term','Credit_History','dependent']]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.3)
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(xtrain,ytrain)
model.predict([[4538,360.0,1.0,1]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ...
